# %% [markdown]
# <a href="https://colab.research.google.com/github/Nani9966/ANN/blob/main/ANN_FSDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.9.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/content/aps_data.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (81) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (5000, 171)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  ...  \
# 0   neg       6      0      0      0      0      0      0      0      0  ...
# 1   neg      90      0      0     66      0      0      0      0      0  ...
# 2   neg      30     na     16     14      0      0      0      0      0  ...
# 3   neg     444     na     14     12      0      0      0      0      0  ...
# 4   neg      82     na     12     10      0      0      0      0   1464  ...
#
#   ee_002 ee_003 ee_004 ee_005 ee_006 ee_007 ee_008 ee_009 ef_000 eg_000
# 0     26      8     26     52      0      0      0      0      0      0
# 1   1268    526    554    300    118    260      0      0      0      0
# 2    480     84     74     50     46      0      0      0      0      0
# 3   1614   1144   3598   2460   1258   8524    110      0      0      0
# 4   1010    132    310     56     92   1292      0      0      0      0
#
# [5 rows x 171 columns]

# %%
dataset=df.replace("na",np.nan)

# %%
dataset.isnull().sum()
# Out:
# class        0
# aa_000       0
# ab_000    3849
# ac_000     308
# ad_000    1236
#           ...
# ee_007      58
# ee_008      58
# ee_009      58
# ef_000     242
# eg_000     242
# Length: 171, dtype: int64

# %%
dataset.isnull().sum().sort_values()
# Out:
# class        0
# aa_000       0
# bt_000      12
# ck_000      38
# cj_000      38
#           ...
# ab_000    3849
# cr_000    3849
# bp_000    3960
# bq_000    4043
# br_000    4105
# Length: 171, dtype: int64

# %%
pd.options.display.max_rows=1000

# %%
# dataset.isnull().sum()

pd.DataFrame(dataset.isnull().sum().sort_values(ascending=False)).rename(columns={0:"Null valuse count"})
# Out:
#         Null valuse count
# br_000               4105
# bq_000               4043
# bp_000               3960
# ab_000               3849
# cr_000               3849
# bo_000               3832
# bn_000               3631
# bm_000               3273
# bl_000               2234
# bk_000               1880
# ch_000               1236
# co_000               1236
# cf_000               1236
# cg_000               1236
# ad_000               1236
# db_000               1150
# ct_000               1150
# cu_000               1150
# cv_000               1150
# cx_000               1150
# cy_000               1150
# cz_000               1150
# da_000               1150
# dc_000               1150
# ec_00                 837
# cm_000                796
# cl_000                778
# ed_000                778
# ak_000                384
# ca_000                383
# di_000                361
# df_000                361
# dg_000                361
# dh_000                361
# ...
